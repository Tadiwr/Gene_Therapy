# %%
import pandas as pd
import datetime as dt
from sklearn.preprocessing import LabelEncoder

df = pd.read_csv("./Dataset.csv")
df.head()
# Out:
#    AAVDB   NCT Number                                              Title  \
# 0      1  NCT02341807  Safety and Dose Escalation Study of AAV2-hCHM ...
# 1      3  NCT02396342  Trial of AAV5-hFIX in Severe or Moderately Sev...
# 2      4  NCT01637805  Clinical Safety and Preliminary Efficacy of AA...
# 3      6  NCT03496012  Efficacy and Safety of AAV2-REP1 for the Treat...
# 4      7  NCT03252847  Gene Therapy for X-linked Retinitis Pigmentosa...
#
#     Drug ID                  Status  No of pts Vector Safety met Efficacy met  \
# 0  SPK-7001  Active, not recruiting       10.0   AAV2        Yes           No
# 1   AMT-061  Active, not recruiting       10.0   AAV5        Yes          Yes
# 2       NaN          Unknown status       20.0    NaN        NaN          NaN
# 3  BIIB-111              Recruiting       14.0   AAV2        Yes          Yes
# 4     A-004              Recruiting       36.0   AAV2        NaN          NaN
#
#   Administration Therapeutic route  Administration Therapeutic Area  \
# 0                        Subretinal                   Ophthalmology
# 1                       Intravenous                      Hematology
# 2                               NaN                        Oncology
# 3                        Subretinal                   Ophthalmology
# 4                               NaN                   Ophthalmology
#
#       Phases Primary Completion
# 0  Phase 1/2          1/10/2019
# 1  Phase 1/2           1/5/2021
# 2    Phase 1          1/10/2016
# 3    Phase 3         31/03/2020
# 4         ??          1/11/2020

# %%
df.columns
# Out:
# Index(['AAVDB', 'NCT Number', 'Title', 'Drug ID', 'Status', 'No of pts',
#        'Vector', 'Safety met', 'Efficacy met',
#        'Administration Therapeutic route ', 'Administration Therapeutic Area',
#        'Phases', 'Primary Completion'],
#       dtype='object')

# %% [markdown]
# Data Cleaning

# %%
data = df.drop(columns=['AAVDB', 'NCT Number'])
data
# Out:
#                                                  Title     Drug ID  \
# 0    Safety and Dose Escalation Study of AAV2-hCHM ...    SPK-7001
# 1    Trial of AAV5-hFIX in Severe or Moderately Sev...     AMT-061
# 2    Clinical Safety and Preliminary Efficacy of AA...         NaN
# 3    Efficacy and Safety of AAV2-REP1 for the Treat...    BIIB-111
# 4    Gene Therapy for X-linked Retinitis Pigmentosa...       A-004
# ..                                                 ...         ...
# 147  Safety and Efficacy Study of rAAV.sFlt-1 in Pa...     AVA-101
# 148           Gene Therapy Clinical Study in Adult PKU     HMI-102
# 149  Dose-escalation Study to Evaluate the Safety a...      GS-030
# 150  Phase 1 Dose Escalation Study of Intra-Articul...     tgAAC94
# 151  Intracerebral Gene Therapy for Sanfilippo Type...  LYSSAF-301
#
#                      Status  No of pts    Vector Safety met Efficacy met  \
# 0    Active, not recruiting       10.0      AAV2        Yes           No
# 1    Active, not recruiting       10.0      AAV5        Yes          Yes
# 2            Unknown status       20.0       NaN        NaN          NaN
# 3                Recruiting       14.0      AAV2        Yes          Yes
# 4                Recruiting       36.0      AAV2        NaN          NaN
# ..                      ...        ...       ...        ...          ...
# 147               Completed       40.0      AAV2        NaN          NaN
# 148              Recruiting       21.0  AAVHSC15        NaN          NaN
# 149              Recruiting       18.0  AAV2/7m8        NaN          NaN
# 150               Completed       15.0      AAV2        Yes           No
# 151               Completed        4.0   AAVrh10        Yes          NaN
#
#     Administration Therapeutic route  Administration Therapeutic Area  \
# 0                          Subretinal                   Ophthalmology
# 1                         Intravenous                      Hematology
# 2                                 NaN                        Oncology
# 3                          Subretinal                   Ophthalmology
# 4                                 NaN                   Ophthalmology
# ..                                ...                             ...
# 147                               NaN                   Ophthalmology
# 148                       Intravenous                       Metabolic
# 149                               NaN                   Ophthalmology
# 150                               NaN                      Autoimmune
# 151                               NaN                       Metabolic
#
#         Phases Primary Completion
# 0    Phase 1/2          1/10/2019
# 1    Phase 1/2           1/5/2021
# 2      Phase 1          1/10/2016
# 3      Phase 3         31/03/2020
# 4           ??          1/11/2020
# ..         ...                ...
# 147  Phase 1/2           1/5/2017
# 148  Phase 1/2           1/6/2021
# 149  Phase 1/2           1/9/2020
# 150    Phase 1          1/11/2005
# 151  Phase 1/2           1/5/2013
#
# [152 rows x 11 columns]

# %% [markdown]
# Removing Null Values

# %%
data["Efficacy met"].unique()
# Out:
# array(['No', 'Yes', nan, 'Yes but comparable to placebo in other studies',
#        'Yes??', 'Preliminary', 'yes'], dtype=object)

# %%
dates = data["Primary Completion"]

for x in range(len(data)):
    date = dates[x]
    date = str(date).split("/")
    data["Primary Completion"][x] = date[2]

data
# Out:
# C:\Users\tadiw\AppData\Local\Temp\ipykernel_20008\3703311620.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Primary Completion"][x] = date[2]
#                                                  Title     Drug ID  \
# 0    Safety and Dose Escalation Study of AAV2-hCHM ...    SPK-7001
# 1    Trial of AAV5-hFIX in Severe or Moderately Sev...     AMT-061
# 2    Clinical Safety and Preliminary Efficacy of AA...         NaN
# 3    Efficacy and Safety of AAV2-REP1 for the Treat...    BIIB-111
# 4    Gene Therapy for X-linked Retinitis Pigmentosa...       A-004
# ..                                                 ...         ...
# 147  Safety and Efficacy Study of rAAV.sFlt-1 in Pa...     AVA-101
# 148           Gene Therapy Clinical Study in Adult PKU     HMI-102
# 149  Dose-escalation Study to Evaluate the Safety a...      GS-030
# 150  Phase 1 Dose Escalation Study of Intra-Articul...     tgAAC94
# 151  Intracerebral Gene Therapy for Sanfilippo Type...  LYSSAF-301
#
#                      Status  No of pts    Vector Safety met Efficacy met  \
# 0    Active, not recruiting       10.0      AAV2        Yes           No
# 1    Active, not recruiting       10.0      AAV5        Yes          Yes
# 2            Unknown status       20.0       NaN        NaN          NaN
# 3                Recruiting       14.0      AAV2        Yes          Yes
# 4                Recruiting       36.0      AAV2        NaN          NaN
# ..                      ...        ...       ...        ...          ...
# 147               Completed       40.0      AAV2        NaN          NaN
# 148              Recruiting       21.0  AAVHSC15        NaN          NaN
# 149              Recruiting       18.0  AAV2/7m8        NaN          NaN
# 150               Completed       15.0      AAV2        Yes           No
# 151               Completed        4.0   AAVrh10        Yes          NaN
#
#     Administration Therapeutic route  Administration Therapeutic Area  \
# 0                          Subretinal                   Ophthalmology
# 1                         Intravenous                      Hematology
# 2                                 NaN                        Oncology
# 3                          Subretinal                   Ophthalmology
# 4                                 NaN                   Ophthalmology
# ..                                ...                             ...
# 147                               NaN                   Ophthalmology
# 148                       Intravenous                       Metabolic
# 149                               NaN                   Ophthalmology
# 150                               NaN                      Autoimmune
# 151                               NaN                       Metabolic
#
#         Phases Primary Completion
# 0    Phase 1/2               2019
# 1    Phase 1/2               2021
# 2      Phase 1               2016
# 3      Phase 3               2020
# 4           ??               2020
# ..         ...                ...
# 147  Phase 1/2               2017
# 148  Phase 1/2               2021
# 149  Phase 1/2               2020
# 150    Phase 1               2005
# 151  Phase 1/2               2013
#
# [152 rows x 11 columns]

# %%
data.columns
# Out:
# Index(['Title', 'Drug ID', 'Status', 'No of pts', 'Vector', 'Safety met',
#        'Efficacy met', 'Administration Therapeutic route ',
#        'Administration Therapeutic Area', 'Phases', 'Primary Completion'],
#       dtype='object')

# %%
df = data.dropna(subset=[
    "Efficacy met",
    "Vector",
    "Safety met",
    "Administration Therapeutic route ",
    "Administration Therapeutic Area",
    "Phases",
    "Drug ID"
])
df.head()
# Out:
#                                                 Title    Drug ID  \
# 0   Safety and Dose Escalation Study of AAV2-hCHM ...   SPK-7001
# 1   Trial of AAV5-hFIX in Severe or Moderately Sev...    AMT-061
# 3   Efficacy and Safety of AAV2-REP1 for the Treat...   BIIB-111
# 11         AAV2-GDNF for Advanced Parkinson?s Disease    AMT-090
# 13  A Study of AAV-hAADC-2 in Subjects With Parkin...  VYAADC-01
#
#                     Status  No of pts Vector Safety met  \
# 0   Active, not recruiting       10.0   AAV2        Yes
# 1   Active, not recruiting       10.0   AAV5        Yes
# 3               Recruiting       14.0   AAV2        Yes
# 11  Active, not recruiting       13.0   AAV2        Yes
# 13               Completed       10.0   AAV1        Yes
#
#                                       Efficacy met  \
# 0                                               No
# 1                                              Yes
# 3                                              Yes
# 11                                             Yes
# 13  Yes but comparable to placebo in other studies
#
#    Administration Therapeutic route  Administration Therapeutic Area  \
# 0                         Subretinal                   Ophthalmology
# 1                        Intravenous                      Hematology
# 3                         Subretinal                   Ophthalmology
# 11                      Intracranial                       Neurology
# 13                      Intracranial                       Neurology
#
#        Phases Primary Completion
# 0   Phase 1/2               2019
# 1   Phase 1/2               2021
# 3     Phase 3               2020
# 11    Phase 1               2022
# 13    Phase 1               2013

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 60 entries, 0 to 146
# Data columns (total 11 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Title                              60 non-null     object
#  1   Drug ID                            60 non-null     object
#  2   Status                             60 non-null     object
#  3   No of pts                          60 non-null     float64
#  4   Vector                             60 non-null     object
#  5   Safety met                         60 non-null     object
#  6   Efficacy met                       60 non-null     object
#  7   Administration Therapeutic route   60 non-null     object
#  8   Administration Therapeutic Area    60 non-null     object
#  9   Phases                             60 non-null     object
#  10  Primary Completion                 60 non-null     object
# dtypes: float64(1), object(10)
# memory usage: 5.6+ KB

# %% [markdown]
# # Lable Encoding the Eficacy Met COlumn

# %%
y = data["Efficacy met"]
y.unique()
# Out:
# array(['No', 'Yes', nan, 'Yes but comparable to placebo in other studies',
#        'Yes??', 'Preliminary', 'yes'], dtype=object)

# %%
# encoder = LabelEncoder()
# eff = encoder.fit_transform(data["Efficacy met"])
# eff

# %%
df.to_csv("cleaned_dataset.csv")
